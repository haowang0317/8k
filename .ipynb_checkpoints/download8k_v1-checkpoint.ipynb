# %% [markdown]
# # 基本設定

# %%
# 可調參數
EXCEL_PATH = "/Users/wanghao/8k/8K_Filings.xlsx"
SHEET_INDEX = 0

HTML_DIR = "/Volumes/One Touch/8k_file_html"
TXT_DIR  = "/Volumes/One Touch/8k_file_txt"
OTHER_DIR = "/Volumes/One Touch/8k_file_neither"

DRY_RUN = True   # True: 先跑少量測試
DRY_RUN_N = 250

MIN_INTERVAL = 0.25
USER_AGENT = (
    "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 "
    "(KHTML, like Gecko) Chrome Safari (Contact: haowang5277@gmail.com)"
)
SEC_PREFIX = "https://www.sec.gov/"

# %% [markdown]
# # 匯入套件

# %%
import re
import os
import time
from typing import List, Optional

import pandas as pd
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse, parse_qs

# %% [markdown]
# # 讀 Excel 與去重複函式

# %%
start = time.perf_counter()

KEEP = ["coname", "cik", "accession"]

def keep_and_dedupe(df: pd.DataFrame) -> pd.DataFrame:
    out = df.copy()
    out.columns = [c.strip() for c in out.columns]
    return out[KEEP].drop_duplicates(subset=["cik", "accession"], keep="first")

df_raw = pd.read_excel(EXCEL_PATH, sheet_name=SHEET_INDEX)
res = keep_and_dedupe(df_raw)

print(f"刪減後（列, 欄）= {res.shape}")
print(res.head())

end = time.perf_counter()
print(f"花費時間：{end - start:.2f} 秒")
# Out:
# 刪減後（列, 欄）= (835233, 3)
#                                coname     cik             accession
# 0                   SOUTHERN UNION CO  203248  0000913907-94-000002
# 1  CLEVELAND ELECTRIC ILLUMINATING CO   20947  0000774197-94-000001
# 2                    TOLEDO EDISON CO  352049  0000774197-94-000001
# 3                    BROOKE GROUP LTD   59440  0000950123-94-000010
# 4                    MDC HOLDINGS INC  773141  0000950109-94-000014
# 花費時間：36.93 秒

# %% [markdown]
# # HTTP 與速率控制

# %%
class FatalError(RuntimeError):
    pass

_last_call_ts = 0.0

def _rate_limit(): #控制下載頻率，確保請求間隔不低於 MIN_INTERVAL 秒
    global _last_call_ts
    now = time.monotonic()
    wait = (_last_call_ts + MIN_INTERVAL) - now
    if wait > 0:
        time.sleep(wait)
    _last_call_ts = time.monotonic()

def _get(url: str, stream: bool = False) -> requests.Response: #對單一 URL 發送 GET 請求，內建重試、錯誤處理和限速
    _rate_limit()
    try:
        r = requests.get(url, headers={"User-Agent": USER_AGENT}, timeout=30, stream=stream)
        if r.status_code == 429:
            ra = r.headers.get("Retry-After")
            sleep_s = int(ra) if ra and ra.isdigit() else 5
            print(f"[429] Too Many Requests: 等待 {sleep_s} 秒後重試...")
            time.sleep(sleep_s)
            _rate_limit()
            r = requests.get(url, headers={"User-Agent": USER_AGENT}, timeout=30, stream=stream)
        if r.status_code != 200:
            raise FatalError(f"HTTP {r.status_code}: {url}")
        return r
    except requests.RequestException as e:
        raise FatalError(f"請求失敗: {url}: {e}")

# %% [markdown]
# # 找到要的下載連結函式

# %%
_HTML_EXTS = (".htm", ".html")
_TXT_EXTS = (".txt",)

def _find_primary_doc_url(index_html: str) -> str:
    soup = BeautifulSoup(index_html, "html.parser")

    # 找 Document Format Files 表格
    table = None
    for t in soup.find_all("table"):
        ths = [th.get_text(strip=True).lower() for th in t.find_all("th")]
        if {"seq", "description", "document", "type", "size"} <= set(ths):
            table = t
            break
    if table is None:
        raise FatalError("找不到 Document Format Files 表格")

    ths = [th.get_text(strip=True).lower() for th in table.find_all("th")]
    col = {name: ths.index(name) for name in ["seq", "description", "document", "type", "size"]}

    # 目標表單：8-K 家族
    keywords = ("8-k", "8-k/a")

    candidates_html = []
    candidates_txt = []

    for tr in table.find_all("tr"):
        tds = tr.find_all("td")
        if len(tds) <= max(col.values()):
            continue

        type_txt = tds[col["type"]].get_text(strip=True).lower()

        # 等於或前綴（更準確，避免誤抓）
        if not any(type_txt == k or type_txt.startswith(k) for k in keywords):
            continue

        for a in tds[col["document"]].find_all("a", href=True):
            raw = a["href"].strip()
            low = raw.lower()

            # 處理 iXBRL 連結：/ix?doc=...
            if low.startswith("/ix?") or "/ix?" in low:
                q = urlparse(raw).query
                doc = parse_qs(q).get("doc", [None])[0]
                if doc:
                    raw = doc
                    low = raw.lower()

            # 避免 viewer 殼連結
            if "viewer" in low and ("doc=" not in low) and not low.endswith(_HTML_EXTS + _TXT_EXTS):
                continue

            # 只接受 .htm/.html/.txt
            if not low.endswith(_HTML_EXTS + _TXT_EXTS):
                continue

            abs_url = urljoin(SEC_PREFIX, raw)
            if low.endswith(_HTML_EXTS):
                candidates_html.append(abs_url)
            else:
                candidates_txt.append(abs_url)

    # 優先回傳 HTML，再回傳 TXT
    if candidates_html:
        return candidates_html[0]
    if candidates_txt:
        return candidates_txt[0]

    # --- Fallback：沒匹配到 Type，挑第一個 HTML/TXT ---
    for tr in table.find_all("tr"):
        tds = tr.find_all("td")
        if len(tds) <= max(col.values()):
            continue
        for a in tds[col["document"]].find_all("a", href=True):
            raw = a["href"].strip()
            low = raw.lower()

            if low.startswith("/ix?") or "/ix?" in low:
                q = urlparse(raw).query
                doc = parse_qs(q).get("doc", [None])[0]
                if doc:
                    raw = doc
                    low = raw.lower()

            if low.endswith(_HTML_EXTS):
                return urljoin(SEC_PREFIX, raw)
            if low.endswith(_TXT_EXTS):
                candidates_txt.append(urljoin(SEC_PREFIX, raw))

    if candidates_txt:
        return candidates_txt[0]

    raise FatalError("找不到符合 8-K/8-KA 的主檔連結，且沒有可用的 fallback")

# %% [markdown]
# # 組出 Index URL + 下載函式

# %%
def _sanitize_filename(name: str) -> str:
    """移除檔名中不合法的字元並用底線取代空白"""
    name = re.sub(r'[\\/*?:"<>|]', "", name)
    name = name.replace(" ", "_")
    return name.strip()

def _make_index_url(cik: str, accession: str) -> str:
    acc_no_dash = accession.replace("-", "")
    return f"https://www.sec.gov/Archives/edgar/data/{int(cik)}/{acc_no_dash}/{accession}-index.html"

def _ensure_dirs(*dirs):
    for d in dirs:
        os.makedirs(d, exist_ok=True)

def download_10k(df: pd.DataFrame, limit: int = 100) -> List[str]:
    #_ensure_dirs(HTML_DIR, TXT_DIR, OTHER_DIR)
    urls = [_make_index_url(row.cik, row.accession) for _, row in df.iterrows()]
    urls = urls[:limit]

    saved = []
    errors = []

    start_t = time.time()
    for i, (_, row) in enumerate(df.iloc[:limit].iterrows(), 1):
        coname_safe = _sanitize_filename(row.coname)
        accession_safe = _sanitize_filename(row.accession)
        url = _make_index_url(row.cik, row.accession)

        try:
            index_resp = _get(url)
            primary_url = _find_primary_doc_url(index_resp.text)
            resp = _get(primary_url, stream=True)

            # 檔名格式：公司名_accession.html
            filename = f"{coname_safe}_{accession_safe}"
            if primary_url.lower().endswith(_HTML_EXTS):
                path = os.path.join(HTML_DIR, f"{filename}.html")
            elif primary_url.lower().endswith(_TXT_EXTS):
                path = os.path.join(TXT_DIR, f"{filename}.txt")
            else:
                path = os.path.join(OTHER_DIR, f"{filename}.dat")

            # 寫入檔案
            with open(path, "wb") as f:
                for chunk in resp.iter_content(chunk_size=1024 * 64):
                    if chunk:
                        f.write(chunk)

            saved.append(path)
            print(f"[OK] {i}/{len(urls)} -> {path}")

        except Exception as e:
            errors.append({
                "coname": row.coname,
                "accession": row.accession,
                "index_url": url,
                "error": str(e)
            })
            print(f"[ERR] {i}/{len(urls)}: {e}")

    print(f"\n✅ 成功下載 {len(saved)} 檔，失敗 {len(errors)} 檔；耗時 {time.time() - start_t:.2f} 秒")

    if errors:
        errors_df = pd.DataFrame(errors)
        errors_df.to_csv("download_errors.csv", index=False, encoding="utf-8-sig")
        print(f"❗ 已記錄失敗清單到 download_errors.csv ({len(errors)} 筆)")

    return saved

# %% [markdown]
# # 執行下載

# %%
if DRY_RUN:
    df_slice = res.iloc[:DRY_RUN_N]
else:
    df_slice = res

print(f"本次處理筆數：{len(df_slice)}")
saved_files = download_10k(df_slice, limit=len(df_slice))
# Out:
# 本次處理筆數：250
# [OK] 1/250 -> /Volumes/One Touch/8k_file_txt/SOUTHERN_UNION_CO_0000913907-94-000002.txt
# [OK] 2/250 -> /Volumes/One Touch/8k_file_txt/CLEVELAND_ELECTRIC_ILLUMINATING_CO_0000774197-94-000001.txt
# [OK] 3/250 -> /Volumes/One Touch/8k_file_txt/TOLEDO_EDISON_CO_0000774197-94-000001.txt
# [OK] 4/250 -> /Volumes/One Touch/8k_file_txt/BROOKE_GROUP_LTD_0000950123-94-000010.txt
# [OK] 5/250 -> /Volumes/One Touch/8k_file_txt/MDC_HOLDINGS_INC_0000950109-94-000014.txt
# [OK] 6/250 -> /Volumes/One Touch/8k_file_txt/CENTRAL_HUDSON_GAS_&_ELECTRIC_CORP_0000018647-94-000001.txt
# [OK] 7/250 -> /Volumes/One Touch/8k_file_txt/CITIZENS_UTILITIES_CO_0000020520-94-000001.txt
# [OK] 8/250 -> /Volumes/One Touch/8k_file_txt/PRICE_COMMUNICATIONS_CORP_0000897446-94-000004.txt
# [OK] 9/250 -> /Volumes/One Touch/8k_file_txt/KAYDON_CORP_0000740694-94-000001.txt
# [OK] 10/250 -> /Volumes/One Touch/8k_file_txt/PENTAIR_INC_0000077360-94-000007.txt
# [OK] 11/250 -> /Volumes/One Touch/8k_file_txt/SILGAN_HOLDINGS_INC_0000896058-94-000003.txt
# [OK] 12/250 -> /Volumes/One Touch/8k_file_txt/MELLON_BANK_CORP_0000950132-94-000006.txt
# [OK] 13/250 -> /Volumes/One Touch/8k_file_txt/BELLSOUTH_CORP_0000732713-94-000001.txt
# [OK] 14/250 -> /Volumes/One Touch/8k_file_txt/OWENS_&_MINOR_INC_0000075252-94-000001.txt
# [OK] 15/250 -> /Volumes/One Touch/8k_file_txt/SPS_TECHNOLOGIES_INC_0000093444-94-000003.txt
# [OK] 16/250 -> /Volumes/One Touch/8k_file_txt/CENTRAL_MAINE_POWER_CO_0000018675-94-000001.txt
# [OK] 17/250 -> /Volumes/One Touch/8k_file_txt/DONNELLEY_R_R_&_SONS_CO_0000950131-94-000008.txt
# [OK] 18/250 -> /Volumes/One Touch/8k_file_txt/FOOD_LION_INC_0000037912-94-000003.txt
# [OK] 19/250 -> /Volumes/One Touch/8k_file_txt/IES_UTILITIES_INC_0000052485-94-000003.txt
# [OK] 20/250 -> /Volumes/One Touch/8k_file_txt/COOPER_COMPANIES_INC_0000950117-94-000004.txt
# [OK] 21/250 -> /Volumes/One Touch/8k_file_txt/MAGNETEK_INC_0000912057-94-000034.txt
# [OK] 22/250 -> /Volumes/One Touch/8k_file_txt/TOLL_BROTHERS_INC_0000950115-94-000008.txt
# [OK] 23/250 -> /Volumes/One Touch/8k_file_txt/IMC_FERTILIZER_GROUP_INC_0000820626-94-000002.txt
# [OK] 24/250 -> /Volumes/One Touch/8k_file_txt/FREEPORT_MCMORAN_COPPER_&_GOLD_INC_0000950103-94-000010.txt
# [OK] 25/250 -> /Volumes/One Touch/8k_file_txt/STONE_CONTAINER_CORP_0000912057-94-000037.txt
# [OK] 26/250 -> /Volumes/One Touch/8k_file_txt/NATIONAL_STEEL_CORP_0000950172-94-000001.txt
# [OK] 27/250 -> /Volumes/One Touch/8k_file_txt/OLIN_CORP_0000074303-94-000002.txt
# [OK] 28/250 -> /Volumes/One Touch/8k_file_txt/DISCOVER_CREDIT_CORP_0000815743-94-000001.txt
# [OK] 29/250 -> /Volumes/One Touch/8k_file_txt/PENTAIR_INC_0000077360-94-000038.txt
# [OK] 30/250 -> /Volumes/One Touch/8k_file_txt/TEXAS_INSTRUMENTS_INC_0000097476-94-000002.txt
# [OK] 31/250 -> /Volumes/One Touch/8k_file_txt/SOUTHEASTERN_MICHIGAN_GAS_ENTERPRISES_INC_0000950124-94-000108.txt
# [OK] 32/250 -> /Volumes/One Touch/8k_file_txt/FORD_MOTOR_CREDIT_CO_0000038009-94-000005.txt
# [OK] 33/250 -> /Volumes/One Touch/8k_file_txt/CITADEL_HOLDING_CORP_0000898430-94-000043.txt
# [OK] 34/250 -> /Volumes/One Touch/8k_file_txt/MASCOTECH_INC_0000950124-94-000115.txt
# [OK] 35/250 -> /Volumes/One Touch/8k_file_txt/PACIFIC_GAS_&_ELECTRIC_CO_0000075488-94-000001.txt
# [OK] 36/250 -> /Volumes/One Touch/8k_file_txt/MDC_HOLDINGS_INC_0000950109-94-000045.txt
# [OK] 37/250 -> /Volumes/One Touch/8k_file_txt/DELTA_WOODSIDE_INDUSTRIES_INC_SC_0000806624-94-000002.txt
# [OK] 38/250 -> /Volumes/One Touch/8k_file_txt/VIACOM_INC_0000950112-94-000048.txt
# [OK] 39/250 -> /Volumes/One Touch/8k_file_txt/FREEPORT_MCMORAN_COPPER_&_GOLD_INC_0000950103-94-000022.txt
# [OK] 40/250 -> /Volumes/One Touch/8k_file_txt/UNION_PLANTERS_CORP_0000950144-94-000039.txt
# [OK] 41/250 -> /Volumes/One Touch/8k_file_txt/UNION_PLANTERS_CORP_0000950144-94-000045.txt
# [OK] 42/250 -> /Volumes/One Touch/8k_file_txt/CENTURY_TELEPHONE_ENTERPRISES_INC_0000906280-94-000003.txt
# [OK] 43/250 -> /Volumes/One Touch/8k_file_txt/GTE_NORTH_INC_0000040867-94-000019.txt
# [OK] 44/250 -> /Volumes/One Touch/8k_file_txt/GTE_SOUTH_INC_0000040878-94-000023.txt
# [OK] 45/250 -> /Volumes/One Touch/8k_file_txt/LOMAS_FINANCIAL_CORP_0000060150-94-000001.txt
# [OK] 46/250 -> /Volumes/One Touch/8k_file_txt/NEW_YORK_TELEPHONE_CO_0000071689-94-000001.txt
# [OK] 47/250 -> /Volumes/One Touch/8k_file_txt/OSHKOSH_B_GOSH_INC_0000075042-94-000001.txt
# [OK] 48/250 -> /Volumes/One Touch/8k_file_txt/SCANA_CORP_0000754737-94-000001.txt
# [OK] 49/250 -> /Volumes/One Touch/8k_file_txt/BEAR_STEARNS_COMPANIES_INC_0000777001-94-000001.txt
# [OK] 50/250 -> /Volumes/One Touch/8k_file_txt/PUBLIC_SERVICE_CO_OF_NEW_MEXICO_0000081023-94-000001.txt
# [OK] 51/250 -> /Volumes/One Touch/8k_file_txt/SEAFIELD_CAPITAL_CORP_0000830158-94-000002.txt
# [OK] 52/250 -> /Volumes/One Touch/8k_file_txt/SOUTH_CAROLINA_ELECTRIC_&_GAS_CO_0000091882-94-000001.txt
# [OK] 53/250 -> /Volumes/One Touch/8k_file_txt/BANK_OF_NEW_YORK_CO_INC_0000009626-94-000001.txt
# [OK] 54/250 -> /Volumes/One Touch/8k_file_txt/DEERE_&_CO_0000315189-94-000001.txt
# [OK] 55/250 -> /Volumes/One Touch/8k_file_txt/GTE_CALIFORNIA_INC_0000040864-94-000029.txt
# [OK] 56/250 -> /Volumes/One Touch/8k_file_txt/GTE_FLORIDA_INC_0000040865-94-000061.txt
# [OK] 57/250 -> /Volumes/One Touch/8k_file_txt/MOUNTAIN_FUEL_SUPPLY_CO_0000068589-94-000002.txt
# [OK] 58/250 -> /Volumes/One Touch/8k_file_txt/COOPER_COMPANIES_INC_0000950117-94-000007.txt
# [OK] 59/250 -> /Volumes/One Touch/8k_file_txt/RIGGS_NATIONAL_CORP_0000950109-94-000060.txt
# [OK] 60/250 -> /Volumes/One Touch/8k_file_txt/NEW_JERSEY_RESOURCES_CORP_0000950112-94-000083.txt
# [OK] 61/250 -> /Volumes/One Touch/8k_file_txt/FIRST_BANK_SYSTEM_INC_0000912057-94-000098.txt
# [OK] 62/250 -> /Volumes/One Touch/8k_file_txt/GULF_STATES_UTILITIES_CO_0000044570-94-000008.txt
# [OK] 63/250 -> /Volumes/One Touch/8k_file_txt/CIGNA_CORP_0000893220-94-000015.txt
# [OK] 64/250 -> /Volumes/One Touch/8k_file_txt/USAIR_GROUP_INC_0000701345-94-000002.txt
# [OK] 65/250 -> /Volumes/One Touch/8k_file_txt/SOUTHWESTERN_ENERGY_CO_0000007332-94-000003.txt
# [OK] 66/250 -> /Volumes/One Touch/8k_file_txt/ADELPHIA_COMMUNICATIONS_CORP_0000796486-94-000001.txt
# [OK] 67/250 -> /Volumes/One Touch/8k_file_txt/PSI_ENERGY_INC_0000081020-94-000001.txt
# [OK] 68/250 -> /Volumes/One Touch/8k_file_txt/COLUMBIA_GAS_SYSTEM_INC_0000950133-94-000016.txt
# [OK] 69/250 -> /Volumes/One Touch/8k_file_txt/USAIR_INC_NEW_0000714560-94-000003.txt
# [OK] 70/250 -> /Volumes/One Touch/8k_file_txt/SOUTHWESTERN_ENERGY_CO_0000007332-94-000005.txt
# [OK] 71/250 -> /Volumes/One Touch/8k_file_txt/BARD_C_R_INC_NJ_0000009892-94-000002.txt
# [OK] 72/250 -> /Volumes/One Touch/8k_file_txt/UNION_PLANTERS_CORP_0000950144-94-000089.txt
# [OK] 73/250 -> /Volumes/One Touch/8k_file_txt/BLACK_&_DECKER_CORP_0000012355-94-000002.txt
# [OK] 74/250 -> /Volumes/One Touch/8k_file_txt/AIR_PRODUCTS_&_CHEMICALS_INC_DE_0000950123-94-000185.txt
# [OK] 75/250 -> /Volumes/One Touch/8k_file_txt/HIBERNIA_CORP_0000047288-94-000004.txt
# [OK] 76/250 -> /Volumes/One Touch/8k_file_txt/KERR_GROUP_INC_0000950148-94-000028.txt
# [OK] 77/250 -> /Volumes/One Touch/8k_file_txt/MERRILL_LYNCH_&_CO_INC_0000950130-94-000070.txt
# [OK] 78/250 -> /Volumes/One Touch/8k_file_txt/HUBCO_INC_0000911651-94-000002.txt
# [OK] 79/250 -> /Volumes/One Touch/8k_file_txt/GFC_FINANCIAL_CORP_0000950147-94-000002.txt
# [OK] 80/250 -> /Volumes/One Touch/8k_file_txt/CHEMICAL_BANKING_CORP_0000019617-94-000003.txt
# [OK] 81/250 -> /Volumes/One Touch/8k_file_txt/COLUMBIA_GAS_SYSTEM_INC_0000893220-94-000019.txt
# [OK] 82/250 -> /Volumes/One Touch/8k_file_txt/ENSERCH_CORP_0000033015-94-000002.txt
# [OK] 83/250 -> /Volumes/One Touch/8k_file_txt/AMERICAN_NUCLEAR_CORP_0000005550-94-000001.txt
# [OK] 84/250 -> /Volumes/One Touch/8k_file_txt/AMERICAN_TELEPHONE_&_TELEGRAPH_CO_0000005907-94-000002.txt
# [OK] 85/250 -> /Volumes/One Touch/8k_file_txt/PUBLIC_SERVICE_ENTERPRISE_GROUP_INC_0000081033-94-000006.txt
# [OK] 86/250 -> /Volumes/One Touch/8k_file_txt/PUBLIC_SERVICE_ELECTRIC_&_GAS_CO_0000081033-94-000006.txt
# [OK] 87/250 -> /Volumes/One Touch/8k_file_txt/CENTRAL_HUDSON_GAS_&_ELECTRIC_CORP_0000018647-94-000003.txt
# [OK] 88/250 -> /Volumes/One Touch/8k_file_txt/PINNACLE_WEST_CAPITAL_CORP_0000950147-94-000003.txt
# [OK] 89/250 -> /Volumes/One Touch/8k_file_txt/FLAGSTAR_COMPANIES_INC_0000852772-94-000001.txt
# [OK] 90/250 -> /Volumes/One Touch/8k_file_txt/USX_CORP_0000950128-94-000001.txt
# [OK] 91/250 -> /Volumes/One Touch/8k_file_txt/VULCAN_MATERIALS_CO_0000103973-94-000002.txt
# [OK] 92/250 -> /Volumes/One Touch/8k_file_txt/HALLIBURTON_CO_0000045012-94-000002.txt
# [OK] 93/250 -> /Volumes/One Touch/8k_file_txt/AMERICAN_EXPRESS_CO_0000004962-94-000001.txt
# [OK] 94/250 -> /Volumes/One Touch/8k_file_txt/USAIR_GROUP_INC_0000714560-94-000007.txt
# [OK] 95/250 -> /Volumes/One Touch/8k_file_txt/USAIR_INC_NEW_0000714560-94-000006.txt
# [OK] 96/250 -> /Volumes/One Touch/8k_file_txt/BELLSOUTH_CORP_0000732713-94-000002.txt
# [OK] 97/250 -> /Volumes/One Touch/8k_file_txt/CITY_NATIONAL_CORP_0000950148-94-000035.txt
# [OK] 98/250 -> /Volumes/One Touch/8k_file_txt/AMSOUTH_BANCORPORATION_0000950109-94-000077.txt
# [OK] 99/250 -> /Volumes/One Touch/8k_file_txt/FLORIDA_PROGRESS_CORP_0000357261-94-000002.txt
# [OK] 100/250 -> /Volumes/One Touch/8k_file_txt/FLORIDA_POWER_CORP_0000357261-94-000002.txt
# [OK] 101/250 -> /Volumes/One Touch/8k_file_txt/PNC_BANK_CORP_0000950128-94-000002.txt
# [OK] 102/250 -> /Volumes/One Touch/8k_file_txt/PACIFIC_GAS_&_ELECTRIC_CO_0000075488-94-000002.txt
# [OK] 103/250 -> /Volumes/One Touch/8k_file_txt/AMERICAN_BRANDS_INC_DE_0000893838-94-000001.txt
# [OK] 104/250 -> /Volumes/One Touch/8k_file_txt/TRAVELERS_INC_0000950112-94-000165.txt
# [OK] 105/250 -> /Volumes/One Touch/8k_file_txt/GFC_FINANCIAL_CORP_0000950147-94-000005.txt
# [OK] 106/250 -> /Volumes/One Touch/8k_file_txt/CENTRAL_MAINE_POWER_CO_0000018675-94-000008.txt
# [OK] 107/250 -> /Volumes/One Touch/8k_file_txt/SALOMON_INC_0000200245-94-000085.txt
# [OK] 108/250 -> /Volumes/One Touch/8k_file_txt/COCA_COLA_CO_0000021344-94-000004.txt
# [OK] 109/250 -> /Volumes/One Touch/8k_file_txt/ADVANCED_MICRO_DEVICES_INC_0000002488-94-000001.txt
# [OK] 110/250 -> /Volumes/One Touch/8k_file_txt/MERRILL_LYNCH_&_CO_INC_0000950130-94-000103.txt
# [OK] 111/250 -> /Volumes/One Touch/8k_file_txt/MERRILL_LYNCH_&_CO_INC_0000950130-94-000104.txt
# [OK] 112/250 -> /Volumes/One Touch/8k_file_txt/ANUHCO_INC_0000719271-94-000004.txt
# [OK] 113/250 -> /Volumes/One Touch/8k_file_txt/BALL_CORP_0000009389-94-000002.txt
# [OK] 114/250 -> /Volumes/One Touch/8k_file_txt/BOSTON_EDISON_CO_0000950135-94-000016.txt
# [OK] 115/250 -> /Volumes/One Touch/8k_file_txt/BROWN_GROUP_INC_0000014707-94-000006.txt
# [OK] 116/250 -> /Volumes/One Touch/8k_file_txt/HELMERICH_&_PAYNE_INC_0000950134-94-000058.txt
# [OK] 117/250 -> /Volumes/One Touch/8k_file_txt/ANUHCO_INC_0000719271-94-000005.txt
# [OK] 118/250 -> /Volumes/One Touch/8k_file_txt/NL_INDUSTRIES_INC_0000950129-94-000048.txt
# [OK] 119/250 -> /Volumes/One Touch/8k_file_txt/PITTSTON_CO_0000078890-94-000003.txt
# [OK] 120/250 -> /Volumes/One Touch/8k_file_txt/SOUTHERN_CO_0000092122-94-000002.txt
# [OK] 121/250 -> /Volumes/One Touch/8k_file_txt/TEXAS_INSTRUMENTS_INC_0000097476-94-000004.txt
# [OK] 122/250 -> /Volumes/One Touch/8k_file_txt/KANSAS_GAS_&_ELECTRIC_CO_KS_0000054496-94-000003.txt
# [OK] 123/250 -> /Volumes/One Touch/8k_file_txt/AMERICAN_NUCLEAR_CORP_0000005550-94-000002.txt
# [OK] 124/250 -> /Volumes/One Touch/8k_file_txt/MERRILL_LYNCH_&_CO_INC_0000950109-94-000095.txt
# [OK] 125/250 -> /Volumes/One Touch/8k_file_txt/NASHUA_CORP_0000950135-94-000018.txt
# [OK] 126/250 -> /Volumes/One Touch/8k_file_txt/USX_CORP_0000950132-94-000017.txt
# [OK] 127/250 -> /Volumes/One Touch/8k_file_txt/WISCONSIN_ELECTRIC_POWER_CO_0000107815-94-000005.txt
# [OK] 128/250 -> /Volumes/One Touch/8k_file_txt/HOUSEHOLD_INTERNATIONAL_INC_0000354964-94-000002.txt
# [OK] 129/250 -> /Volumes/One Touch/8k_file_txt/AMERICAN_TELEPHONE_&_TELEGRAPH_CO_0000005907-94-000004.txt
# [OK] 130/250 -> /Volumes/One Touch/8k_file_txt/BELL_ATLANTIC_CORP_0000950172-94-000010.txt
# [OK] 131/250 -> /Volumes/One Touch/8k_file_txt/WESTERN_GAS_RESOURCES_INC_0000856716-94-000004.txt
# [OK] 132/250 -> /Volumes/One Touch/8k_file_txt/V_F_CORP_PA_0000893220-94-000035.txt
# [OK] 133/250 -> /Volumes/One Touch/8k_file_txt/AIR_PRODUCTS_&_CHEMICALS_INC_DE_0000950123-94-000235.txt
# [OK] 134/250 -> /Volumes/One Touch/8k_file_txt/WESTERN_RESOURCES_INC_KS_0000054507-94-000001.txt
# [OK] 135/250 -> /Volumes/One Touch/8k_file_txt/BELLSOUTH_CORP_0000732713-94-000003.txt
# [OK] 136/250 -> /Volumes/One Touch/8k_file_txt/ML_MEDIA_PARTNERS_LP_0000897446-94-000010.txt
# [OK] 137/250 -> /Volumes/One Touch/8k_file_txt/STANLEY_WORKS_0000093556-94-000001.txt
# [OK] 138/250 -> /Volumes/One Touch/8k_file_txt/AMERICAN_GENERAL_FINANCE_CORP_0000005103-94-000008.txt
# [OK] 139/250 -> /Volumes/One Touch/8k_file_txt/HERTZ_CORP_0000047129-94-000001.txt
# [OK] 140/250 -> /Volumes/One Touch/8k_file_txt/MATTEL_INC_DE_0000063276-94-000002.txt
# [OK] 141/250 -> /Volumes/One Touch/8k_file_txt/MERRILL_LYNCH_&_CO_INC_0000950130-94-000163.txt
# [OK] 142/250 -> /Volumes/One Touch/8k_file_txt/NL_INDUSTRIES_INC_0000950129-94-000059.txt
# [OK] 143/250 -> /Volumes/One Touch/8k_file_txt/CENTRAL_MAINE_POWER_CO_0000018675-94-000009.txt
# [OK] 144/250 -> /Volumes/One Touch/8k_file_txt/ML_MEDIA_PARTNERS_LP_0000897446-94-000012.txt
# [OK] 145/250 -> /Volumes/One Touch/8k_file_txt/UNITED_AIR_LINES_INC_0000950172-94-000015.txt
# [OK] 146/250 -> /Volumes/One Touch/8k_file_txt/SAFECO_CORP_0000086104-94-000002.txt
# [OK] 147/250 -> /Volumes/One Touch/8k_file_txt/STONE_CONTAINER_CORP_0000912057-94-000190.txt
# [OK] 148/250 -> /Volumes/One Touch/8k_file_txt/UNITED_STATES_CELLULAR_CORP_0000096966-94-000009.txt
# [OK] 149/250 -> /Volumes/One Touch/8k_file_txt/TEXAS_INSTRUMENTS_INC_0000097476-94-000006.txt
# [OK] 150/250 -> /Volumes/One Touch/8k_file_txt/FEDERAL_MOGUL_CORP_0000950124-94-000252.txt
# [OK] 151/250 -> /Volumes/One Touch/8k_file_txt/ALUMINUM_CO_OF_AMERICA_0000004281-94-000002.txt
# [OK] 152/250 -> /Volumes/One Touch/8k_file_txt/GULF_STATES_UTILITIES_CO_0000044570-94-000009.txt
# [OK] 153/250 -> /Volumes/One Touch/8k_file_txt/KROGER_CO_0000056873-94-000021.txt
# [OK] 154/250 -> /Volumes/One Touch/8k_file_txt/NASHUA_CORP_0000950135-94-000035.txt
# [OK] 155/250 -> /Volumes/One Touch/8k_file_txt/ALLIED_SIGNAL_INC_0000773840-94-000003.txt
# [OK] 156/250 -> /Volumes/One Touch/8k_file_txt/FREEPORT_MCMORAN_RESOURCE_PARTNERS_LIMITED_PARTNERSHIP_0000950103-94-000066.txt
# [OK] 157/250 -> /Volumes/One Touch/8k_file_txt/CENTRAL_MAINE_POWER_CO_0000018675-94-000010.txt
# [OK] 158/250 -> /Volumes/One Touch/8k_file_txt/CONSOLIDATED_EDISON_CO_OF_NEW_YORK_INC_0000023632-94-000003.txt
# [OK] 159/250 -> /Volumes/One Touch/8k_file_txt/HERTZ_CORP_0000047129-94-000002.txt
# [OK] 160/250 -> /Volumes/One Touch/8k_file_txt/INTERNATIONAL_PAPER_CO_NEW_0000950112-94-000386.txt
# [OK] 161/250 -> /Volumes/One Touch/8k_file_txt/NORTHERN_STATES_POWER_CO_MN_0000072903-94-000004.txt
# [OK] 162/250 -> /Volumes/One Touch/8k_file_txt/BELL_ATLANTIC_CORP_0000893220-94-000061.txt
# [OK] 163/250 -> /Volumes/One Touch/8k_file_txt/FORD_MOTOR_CO_0000037996-94-000003.txt
# [OK] 164/250 -> /Volumes/One Touch/8k_file_txt/HASBRO_INC_0000046080-94-000004.txt
# [OK] 165/250 -> /Volumes/One Touch/8k_file_txt/MATTEL_INC_DE_0000063276-94-000004.txt
# [OK] 166/250 -> /Volumes/One Touch/8k_file_txt/ADVANCED_MICRO_DEVICES_INC_0000002488-94-000002.txt
# [OK] 167/250 -> /Volumes/One Touch/8k_file_txt/FORD_MOTOR_CREDIT_CO_0000950124-94-000267.txt
# [OK] 168/250 -> /Volumes/One Touch/8k_file_txt/KANSAS_CITY_POWER_&_LIGHT_CO_0000054476-94-000001.txt
# [OK] 169/250 -> /Volumes/One Touch/8k_file_txt/AMERICA_WEST_AIRLINES_INC_0000950147-94-000007.txt
# [OK] 170/250 -> /Volumes/One Touch/8k_file_txt/NEW_YORK_TELEPHONE_CO_0000071689-94-000002.txt
# [OK] 171/250 -> /Volumes/One Touch/8k_file_txt/CARDINAL_DISTRIBUTION_INC_0000950130-94-000205.txt
# [OK] 172/250 -> /Volumes/One Touch/8k_file_txt/NL_INDUSTRIES_INC_0000950129-94-000079.txt
# [OK] 173/250 -> /Volumes/One Touch/8k_file_txt/NORTEK_INC_0000950135-94-000065.txt
# [OK] 174/250 -> /Volumes/One Touch/8k_file_txt/WESTERN_GAS_RESOURCES_INC_0000950109-94-000198.txt
# [OK] 175/250 -> /Volumes/One Touch/8k_file_txt/COLUMBIA_HEALTHCARE_CORP_0000860730-94-000001.txt
# [OK] 176/250 -> /Volumes/One Touch/8k_file_txt/STATE_STREET_BOSTON_CORP_0000950135-94-000067.txt
# [OK] 177/250 -> /Volumes/One Touch/8k_file_txt/USX_CORP_0000950128-94-000009.txt
# [OK] 178/250 -> /Volumes/One Touch/8k_file_txt/POGO_PRODUCING_CO_0000230463-94-000001.txt
# [OK] 179/250 -> /Volumes/One Touch/8k_file_txt/HAWAIIAN_ELECTRIC_INDUSTRIES_INC_0000950150-94-000336.txt
# [OK] 180/250 -> /Volumes/One Touch/8k_file_txt/HAWAIIAN_ELECTRIC_CO_INC_0000950150-94-000336.txt
# [OK] 181/250 -> /Volumes/One Touch/8k_file_txt/VALHI_INC_DE_0000950134-94-000110.txt
# [OK] 182/250 -> /Volumes/One Touch/8k_file_txt/MATTEL_INC_DE_0000063276-94-000006.txt
# [OK] 183/250 -> /Volumes/One Touch/8k_file_txt/MINNESOTA_MINING_&_MANUFACTURING_CO_0000066740-94-000002.txt
# [OK] 184/250 -> /Volumes/One Touch/8k_file_txt/NORTEK_INC_0000950135-94-000078.txt
# [OK] 185/250 -> /Volumes/One Touch/8k_file_txt/NORTHERN_STATES_POWER_CO_MN_0000072903-94-000007.txt
# [OK] 186/250 -> /Volumes/One Touch/8k_file_txt/BELL_ATLANTIC_CORP_0000893220-94-000079.txt
# [OK] 187/250 -> /Volumes/One Touch/8k_file_txt/CIGNA_CORP_0000893220-94-000094.txt
# [OK] 188/250 -> /Volumes/One Touch/8k_file_txt/NORWEST_CORP_0000950131-94-000219.txt
# [OK] 189/250 -> /Volumes/One Touch/8k_file_txt/HOUSEHOLD_FINANCE_CORP_0000048681-94-000028.txt
# [OK] 190/250 -> /Volumes/One Touch/8k_file_txt/JERSEY_CENTRAL_POWER_&_LIGHT_CO_0000053456-94-000004.txt
# [OK] 191/250 -> /Volumes/One Touch/8k_file_txt/PENNSYLVANIA_ELECTRIC_CO_0000077227-94-000005.txt
# [OK] 192/250 -> /Volumes/One Touch/8k_file_txt/ENSERCH_CORP_0000033015-94-000003.txt
# [OK] 193/250 -> /Volumes/One Touch/8k_file_txt/ARIZONA_PUBLIC_SERVICE_CO_0000950147-94-000010.txt
# [OK] 194/250 -> /Volumes/One Touch/8k_file_txt/ORANGE_&_ROCKLAND_UTILITIES_INC_0000074778-94-000006.txt
# [OK] 195/250 -> /Volumes/One Touch/8k_file_txt/PORTLAND_GENERAL_ELECTRIC_CO_OR_0000784977-94-000001.txt
# [OK] 196/250 -> /Volumes/One Touch/8k_file_txt/RITE_AID_CORP_0000893220-94-000099.txt
# [OK] 197/250 -> /Volumes/One Touch/8k_file_txt/UNION_PLANTERS_CORP_0000950144-94-000468.txt
# [OK] 198/250 -> /Volumes/One Touch/8k_file_txt/SCIENCE_APPLICATIONS_INTERNATIONAL_CORP_0000912057-94-000609.txt
# [OK] 199/250 -> /Volumes/One Touch/8k_file_txt/FORD_MOTOR_CO_0000037996-94-000004.txt
# [OK] 200/250 -> /Volumes/One Touch/8k_file_txt/ANALOGIC_CORP_0000006284-94-000013.txt
# [OK] 201/250 -> /Volumes/One Touch/8k_file_txt/NIAGARA_MOHAWK_POWER_CORP_NY_0000071932-94-000012.txt
# [OK] 202/250 -> /Volumes/One Touch/8k_file_txt/JWP_INCDE_0000950142-94-000015.txt
# [OK] 203/250 -> /Volumes/One Touch/8k_file_txt/DEERE_JOHN_CAPITAL_CORP_0000027673-94-000004.txt
# [OK] 204/250 -> /Volumes/One Touch/8k_file_txt/PINNACLE_WEST_CAPITAL_CORP_0000950147-94-000011.txt
# [OK] 205/250 -> /Volumes/One Touch/8k_file_txt/AMERICAN_BRANDS_INC_DE_0000893838-94-000002.txt
# [OK] 206/250 -> /Volumes/One Touch/8k_file_txt/KIMBERLY_CLARK_CORP_0000055785-94-000026.txt
# [OK] 207/250 -> /Volumes/One Touch/8k_file_txt/LSB_INDUSTRIES_INC_0000060714-94-000002.txt
# [OK] 208/250 -> /Volumes/One Touch/8k_file_txt/CATERPILLAR_FINANCIAL_SERVICES_CORP_0000764764-94-000020.txt
# [OK] 209/250 -> /Volumes/One Touch/8k_file_txt/AMERICAN_EXPRESS_CO_0000004962-94-000003.txt
# [OK] 210/250 -> /Volumes/One Touch/8k_file_txt/AMERICAN_FINANCIAL_CORP_0000005016-94-000007.txt
# [OK] 211/250 -> /Volumes/One Touch/8k_file_txt/MARSHALL_&_ILSLEY_CORPWI_0000950124-94-000378.txt
# [OK] 212/250 -> /Volumes/One Touch/8k_file_txt/NIAGARA_MOHAWK_POWER_CORP_NY_0000071932-94-000015.txt
# [OK] 213/250 -> /Volumes/One Touch/8k_file_txt/LEHMAN_BROTHERS_INC_0000950123-94-000405.txt
# [OK] 214/250 -> /Volumes/One Touch/8k_file_txt/BELL_ATLANTIC_CORP_0000893220-94-000108.txt
# [OK] 215/250 -> /Volumes/One Touch/8k_file_txt/LEHMAN_BROTHERS_HOLDINGS_INC_0000950123-94-000404.txt
# [OK] 216/250 -> /Volumes/One Touch/8k_file_txt/JPS_TEXTILE_GROUP_INC_DE_0000909518-94-000037.txt
# [OK] 217/250 -> /Volumes/One Touch/8k_file_txt/SUN_CO_INC_0000095304-94-000004.txt
# [OK] 218/250 -> /Volumes/One Touch/8k_file_txt/UNION_PLANTERS_CORP_0000950144-94-000515.txt
# [OK] 219/250 -> /Volumes/One Touch/8k_file_txt/USX_CORP_0000950128-94-000044.txt
# [OK] 220/250 -> /Volumes/One Touch/8k_file_txt/FORD_MOTOR_CREDIT_CO_0000038009-94-000028.txt
# [OK] 221/250 -> /Volumes/One Touch/8k_file_txt/AMREP_CORP_0000912057-94-000677.txt
# [OK] 222/250 -> /Volumes/One Touch/8k_file_txt/NEW_YORK_TELEPHONE_CO_0000071689-94-000005.txt
# [OK] 223/250 -> /Volumes/One Touch/8k_file_txt/NL_INDUSTRIES_INC_0000950129-94-000111.txt
# [OK] 224/250 -> /Volumes/One Touch/8k_file_txt/CASEYS_GENERAL_STORES_INC_0000910066-94-000005.txt
# [OK] 225/250 -> /Volumes/One Touch/8k_file_txt/ADVO_INC_0000950109-94-000317.txt
# [OK] 226/250 -> /Volumes/One Touch/8k_file_txt/COCA_COLA_ENTERPRISES_INC_0000804055-94-000001.txt
# [OK] 227/250 -> /Volumes/One Touch/8k_file_txt/PUBLIC_SERVICE_CO_OF_NEW_MEXICO_0000081023-94-000002.txt
# [OK] 228/250 -> /Volumes/One Touch/8k_file_txt/WESTERN_GAS_RESOURCES_INC_0000856716-94-000006.txt
# [OK] 229/250 -> /Volumes/One Touch/8k_file_txt/TIDEWATER_INC_0000950134-94-000157.txt
# [OK] 230/250 -> /Volumes/One Touch/8k_file_txt/JWP_INCDE_0000950142-94-000017.txt
# [OK] 231/250 -> /Volumes/One Touch/8k_file_txt/AMREP_CORP_0000912057-94-000689.txt
# [OK] 232/250 -> /Volumes/One Touch/8k_file_txt/JERSEY_CENTRAL_POWER_&_LIGHT_CO_0000053456-94-000005.txt
# [OK] 233/250 -> /Volumes/One Touch/8k_file_txt/PENNSYLVANIA_ELECTRIC_CO_0000077227-94-000006.txt
# [OK] 234/250 -> /Volumes/One Touch/8k_file_txt/CENTRAL_LOUISIANA_ELECTRIC_CO_INC_0000018672-94-000006.txt
# [OK] 235/250 -> /Volumes/One Touch/8k_file_txt/GEORGIA_PACIFIC_CORP_0000950144-94-000535.txt
# [OK] 236/250 -> /Volumes/One Touch/8k_file_txt/AMERICA_WEST_AIRLINES_INC_0000706270-94-000002.txt
# [OK] 237/250 -> /Volumes/One Touch/8k_file_txt/JEFFERSON_SMURFIT_CORP_0000950117-94-000039.txt
# [OK] 238/250 -> /Volumes/One Touch/8k_file_txt/TRAVELERS_INC_0000950112-94-000504.txt
# [OK] 239/250 -> /Volumes/One Touch/8k_file_txt/COLUMBIA_HEALTHCARE_CORP_0000860730-94-000006.txt
# [OK] 240/250 -> /Volumes/One Touch/8k_file_txt/SOUTHWEST_GAS_CORP_0000092416-94-000001.txt
# [OK] 241/250 -> /Volumes/One Touch/8k_file_txt/ZAPATA_CORP_0000899243-94-000030.txt
# [OK] 242/250 -> /Volumes/One Touch/8k_file_txt/MADISON_GAS_&_ELECTRIC_CO_0000061339-94-000003.txt
# [OK] 243/250 -> /Volumes/One Touch/8k_file_txt/MASCO_CORP_DE_0000950124-94-000414.txt
# [OK] 244/250 -> /Volumes/One Touch/8k_file_txt/MASCOTECH_INC_0000950124-94-000413.txt
# [OK] 245/250 -> /Volumes/One Touch/8k_file_txt/FREEPORT_MCMORAN_COPPER_&_GOLD_INC_0000950103-94-001894.txt
# [OK] 246/250 -> /Volumes/One Touch/8k_file_txt/SAFECO_CORP_0000086104-94-000004.txt
# [OK] 247/250 -> /Volumes/One Touch/8k_file_txt/HOUSTON_LIGHTING_&_POWER_CO_0000202131-94-000004.txt
# [OK] 248/250 -> /Volumes/One Touch/8k_file_txt/HUBCO_INC_0000911651-94-000007.txt
# [OK] 249/250 -> /Volumes/One Touch/8k_file_txt/PACIFIC_GAS_&_ELECTRIC_CO_0000950131-94-000265.txt
# [OK] 250/250 -> /Volumes/One Touch/8k_file_txt/SNAP_ON_TOOLS_CORP_0000912057-94-000769.txt
#
# ✅ 成功下載 250 檔，失敗 0 檔；耗時 155.85 秒
